# %%
# !HYDRA_FULL_ERROR=1 python my_app.py
# Out:
# [2022-09-23 00:05:17,394][util][INFO] - Disabling python warnings! <config.ignore_warnings=True>
# [2022-09-23 00:05:17,394][util][INFO] - Printing config tree with Rich! <config.print_config=True>
# CONFIG
# ├── datamodule
# │   └── _target_: dataloader.MOT2020Module
# │       batch_size: 5
# │       folder: ./MOT20/
# │       input_h: 480
# │       input_w: 960
# │       image_blur_aug: true
# │       flip: 0
# │       not_max_crop: true
# │       not_rand_crop: true
# │       shift: 0
# │       scale: 0
# │       rotate: 0
# │       aug_rot: 0
# │       same_aug_pre: true
# │       no_color_aug: true
# │       max_frame_dist: 4
# │       down_ratio: 4
# │       pre_hm: true
# │       num_classes: 1
# │       hm_disturb: 0.05
# │       lost_disturb: 0.4
# │       fp_disturb: 0.1
# │       blur_aug:
# │         _target_: util.image.GaussianBlur
# │         kernel_size: 11
# │
# ├── model
# │   └── _target_: models.model.Model
# │       num_queries: 300
# │       num_decoder_stack: 6
# │       num_encoder_stack: 6
# │       hidden_dim: 256
# │       multiscale: true
# │       masks: false
# │       num_classes: 91
# │       backbone:
# │         _target_: models.backbone.build_backbone
# │         lr_backbone: 1.0e-05
# │         position_embedding: sine
# │         hidden_dim: 256
# │         multiscale: true
# │         masks: false
# │         backbone: resnet50
# │         dilation: false
# │       transformer:
# │         _target_: models.transformer.build_transformer
# │         hidden_dim: 256
# │         nheads: 8
# │         num_encoder_layers: 6
# │         num_decoder_layers: 6
# │         dim_feedforward: 2048
# │         dropout: 0.1
# │         activation: relu
# │         return_intermediate_dec: false
# │         num_feature_levels: 4
# │         dec_n_points: 4
# │         enc_n_points: 4
# │         two_stage: false
# │         two_stage_num_proposals: 300
# │         decoder_self_cross: true
# │         sigmoid_attn: false
# │         extra_track_attn: false
# │       matcher:
# │         _target_: models.matcher.build_matcher
# │         set_cost_class: 2
# │         set_cost_bbox: 5
# │         set_cost_giou: 1
# │       weights:
# │         _target_: models.builders.build_weights
# │         loss_ce: 2
# │         loss_bbox: 5
# │         loss_giou: 1
# │         loss_mask: 1
# │         loss_similarity: 0.001
# │         loss_dice: 1
# │
# ├── callbacks
# │   └── model_checkpoint:
# │         _target_: pytorch_lightning.callbacks.ModelCheckpoint
# │         monitor: loss/val
# │         mode: min
# │         save_top_k: 1
# │         save_last: true
# │         verbose: false
# │         dirpath: checkpoints/
# │         filename: epoch_{epoch:03d}
# │         auto_insert_metric_name: false
# │       learning_rate_monitor:
# │         _target_: pytorch_lightning.callbacks.LearningRateMonitor
# │         logging_interval: epoch
# │
# ├── logger
# │   └── tensorboard:
# │         _target_: pytorch_lightning.loggers.tensorboard.TensorBoardLogger
# │         save_dir: tensorboard/
# │         name: null
# │         version: Query Random
# │         log_graph: false
# │         default_hp_metric: true
# │         prefix: ''
# │
# ├── trainer
# │   └── _target_: pytorch_lightning.Trainer
# │       gpus: -1
# │       min_epochs: 1
# │       max_epochs: 12
# │       resume_from_checkpoint: null
# │       precision: 16
# │       gradient_clip_val: 0.1
# │       fast_dev_run: true
# │       default_root_dir: /gpfsdswork/projects/rech/way/uex85wx/ECCVYtVOS/checkp
# │         Random
# │       accelerator: ddp
# │       sync_batchnorm: true
# │
# ├── original_work_dir
# │   └── /gpfsdswork/projects/rech/way/uex85wx/ECCVYtVOS
# ├── data_dir
# │   └── /gpfsdswork/projects/rech/way/uex85wx/ECCVYtVOS/data/
# ├── print_config
# │   └── True
# ├── ignore_warnings
# │   └── True
# ├── train
# │   └── True
# ├── test
# │   └── True
# ├── seed
# │   └── None
# ├── name
# │   └── Query Random
# └── default_hp
#     └── num_queries: 300
#         num_classes: 91
#         num_decoder_stack: 6
#         num_encoder_stack: 6
#         hidden_dim: 256
#         multiscale: true
#         masks: false
#         dim_feedforward: 2048
#         nheads: 8
#         dropout: 0.1
#
# [2022-09-23 00:05:17,478][train][INFO] - Instantiating datamodule <dataloader.MOT2020Module>
# [2022-09-23 00:05:18,952][train][INFO] - Instantiating model <models.model.Model>
# Building Self-Cross Attention.
# Building Self-Cross Attention.
# Created 1
# Created 2
# Created 3
# Created 4
# [2022-09-23 00:05:20,239][train][INFO] - Instantiating callback <pytorch_lightning.callbacks.ModelCheckpoint>
# [2022-09-23 00:05:20,240][train][INFO] - Instantiating callback <pytorch_lightning.callbacks.LearningRateMonitor>
# [2022-09-23 00:05:20,241][train][INFO] - Instantiating logger <pytorch_lightning.loggers.tensorboard.TensorBoardLogger>
# [2022-09-23 00:05:20,243][train][INFO] - Instantiating trainer <pytorch_lightning.Trainer>
# [2022-09-23 00:05:20,249][pytorch_lightning.utilities.distributed][INFO] - GPU available: True, used: True
# [2022-09-23 00:05:20,249][pytorch_lightning.utilities.distributed][INFO] - TPU available: False, using: 0 TPU cores
# [2022-09-23 00:05:20,249][pytorch_lightning.trainer.connectors.accelerator_connector][INFO] - Using native 16bit precision.
# [2022-09-23 00:05:20,250][pytorch_lightning.utilities.distributed][INFO] - Running in fast_dev_run mode: will run a full train, val and test loop using 1 batch(es).
# [2022-09-23 00:05:20,250][train][INFO] - Logging hyperparameters!
# [2022-09-23 00:05:20,253][train][INFO] - Starting training!
# [2022-09-23 00:05:20,254][pytorch_lightning.plugins.training_type.ddp][INFO] - initializing ddp: GLOBAL_RANK: 0, MEMBER: 1/1
# [2022-09-23 00:05:20,255][torch.distributed.distributed_c10d][INFO] - Added key: store_based_barrier_key:1 to store for rank: 0
# [2022-09-23 00:05:20,256][torch.distributed.distributed_c10d][INFO] - Rank 0: Completed store-based barrier for 1 nodes.
# [2022-09-23 00:05:20,256][pytorch_lightning.utilities.distributed][INFO] - ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All DDP processes registered. Starting ddp with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# ./MOT20/train ./MOT20/annotations/train.json
# loading annotations into memory...
# Done (t=5.63s)
# creating index...
# index created!
# Number of Imges, 8931
# Creating video index!
# MOT 2020 is initalized
# [2022-09-23 00:05:27,978][pytorch_lightning.accelerators.gpu][INFO] - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-09-23 00:05:28,199][pytorch_lightning.core.lightning][INFO] -
#    | Name            | Type                  | Params
# -----------------------------------------------------------
# 0  | input_proj      | ModuleList            | 986 K
# 1  | backbone        | Joiner                | 23.5 M
# 2  | class_embed     | Linear                | 23.4 K
# 3  | bbox_embed      | MLP                   | 132 K
# 4  | upsample_layer  | Sequential            | 442 K
# 5  | head_detect_sot | Conv2d                | 8
# 6  | head_class_sot  | Conv2d                | 4
# 7  | head_mask_sot   | Conv2d                | 4
# 8  | transformer     | DeformableTransformer | 17.0 M
# 9  | matcher         | HungarianMatcher      | 0
# 10 | spatial_conv    | Sequential            | 2.3 K
# 11 | temporal_conv   | Sequential            | 524 K
# -----------------------------------------------------------
# 42.3 M    Trainable params
# 222 K     Non-trainable params
# 42.5 M    Total params
# 170.145   Total estimated model params size (MB)
# Epoch 0:   0%|                                            | 0/1 [00:00<?, ?it/s]Error executing job with overrides: []
# Traceback (most recent call last):
#   File "/gpfsdswork/projects/rech/way/uex85wx/ECCVYtVOS/my_app.py", line 14, in <module>
#     my_app()
#   File "/linkhome/rech/gentnt01/uex85wx/.local/lib/python3.9/site-packages/hydra/main.py", line 90, in decorated_main
#     _run_hydra(
#   File "/linkhome/rech/gentnt01/uex85wx/.local/lib/python3.9/site-packages/hydra/_internal/utils.py", line 389, in _run_hydra
#     _run_app(
#   File "/linkhome/rech/gentnt01/uex85wx/.local/lib/python3.9/site-packages/hydra/_internal/utils.py", line 452, in _run_app
#     run_and_report(
#   File "/linkhome/rech/gentnt01/uex85wx/.local/lib/python3.9/site-packages/hydra/_internal/utils.py", line 216, in run_and_report
#     raise ex
#   File "/linkhome/rech/gentnt01/uex85wx/.local/lib/python3.9/site-packages/hydra/_internal/utils.py", line 213, in run_and_report
#     return func()
#   File "/linkhome/rech/gentnt01/uex85wx/.local/lib/python3.9/site-packages/hydra/_internal/utils.py", line 453, in <lambda>
#     lambda: hydra.run(
#   File "/linkhome/rech/gentnt01/uex85wx/.local/lib/python3.9/site-packages/hydra/_internal/hydra.py", line 132, in run
#     _ = ret.return_value
#   File "/linkhome/rech/gentnt01/uex85wx/.local/lib/python3.9/site-packages/hydra/core/utils.py", line 260, in return_value
#     raise self._return_value
#   File "/linkhome/rech/gentnt01/uex85wx/.local/lib/python3.9/site-packages/hydra/core/utils.py", line 186, in run_job
#     ret.return_value = task_function(task_cfg)
#   File "/gpfsdswork/projects/rech/way/uex85wx/ECCVYtVOS/my_app.py", line 11, in my_app
#     return train(cfg)
#   File "/gpfsdswork/projects/rech/way/uex85wx/ECCVYtVOS/train.py", line 84, in train
#     trainer.fit(model=model, datamodule=datamodule)
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py", line 460, in fit
#     self._run(model)
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py", line 758, in _run
#     self.dispatch()
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py", line 799, in dispatch
#     self.accelerator.start_training(self)
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/accelerators/accelerator.py", line 96, in start_training
#     self.training_type_plugin.start_training(trainer)
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/plugins/training_type/training_type_plugin.py", line 144, in start_training
#     self._results = trainer.run_stage()
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py", line 809, in run_stage
#     return self.run_train()
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py", line 871, in run_train
#     self.train_loop.run_training_epoch()
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/trainer/training_loop.py", line 491, in run_training_epoch
#     for batch_idx, (batch, is_last_batch) in train_dataloader:
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/profiler/profilers.py", line 112, in profile_iterable
#     value = next(iterator)
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/trainer/supporters.py", line 530, in prefetch_iterator
#     last = next(it)
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/trainer/supporters.py", line 464, in __next__
#     return self.request_next_batch(self.loader_iters)
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/trainer/supporters.py", line 478, in request_next_batch
#     return apply_to_collection(loader_iters, Iterator, next)
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/pytorch_lightning/utilities/apply_func.py", line 85, in apply_to_collection
#     return function(data, *args, **kwargs)
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 521, in __next__
#     data = self._next_data()
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 561, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/gpfsdswork/projects/rech/way/uex85wx/ECCVYtVOS/dataset/mot20.py", line 228, in __getitem__
#     self._init_ret(ret, gt_det)
#   File "/gpfsdswork/projects/rech/way/uex85wx/ECCVYtVOS/dataset/mot20.py", line 456, in _init_ret
#     max_objs = self.max_objs * self.dense_reg
# AttributeError: 'MOT2020' object has no attribute 'dense_reg'
# Exception ignored in: <function tqdm.__del__ at 0x152a5f363ca0>
# Traceback (most recent call last):
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/tqdm/std.py", line 1152, in __del__
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/tqdm/std.py", line 1306, in close
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/tqdm/std.py", line 1499, in display
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/tqdm/std.py", line 1155, in __str__
#   File "/gpfslocalsup/pub/anaconda-py3/2021.05/envs/pytorch-gpu-1.9.0+py3.9/lib/python3.9/site-packages/tqdm/std.py", line 1457, in format_dict
# TypeError: cannot unpack non-iterable NoneType object

# %%
from dataset.mot20 import build_mot2020

path = r".\MOT20\test"
build_mot2020(folder = path)
# Out:
# .\MOT20\test\train
# loading annotations into memory...
# Done (t=2.38s)
# creating index...
# index created!
# Creating video index!
# MOT 2020 is initalized

# %%
import os

os.environ['HYDRA_FULL_ERROR'] = "1"

# %%
# !git
# Out:
# /bin/bash: git: command not found
